# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers , models

# %%
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print(x_train.shape)
print(x_test.shape)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)

# %%
x_train = x_train / 255.0
x_test = x_test /255.0
print("Preprocessing done!")
# Out:
# Preprocessing done!

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

print("Model created!")
# Out:
# Model created!
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
history = model.fit(x_train, y_train, epochs=5, validation_split=0.1)
# Out:
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8710 - loss: 0.4603 - val_accuracy: 0.9625 - val_loss: 0.1297
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9600 - loss: 0.1363 - val_accuracy: 0.9692 - val_loss: 0.1087
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9731 - loss: 0.0884 - val_accuracy: 0.9703 - val_loss: 0.0999
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9813 - loss: 0.0620 - val_accuracy: 0.9730 - val_loss: 0.0949
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9855 - loss: 0.0482 - val_accuracy: 0.9773 - val_loss: 0.0734

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy: ", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9733 - loss: 0.0921
# Test Accuracy:  0.9764000177383423

# %%
import matplotlib.pyplot as plt
import numpy as np

index = 0   # You can change this number later (0–9999)

plt.imshow(x_test[index], cmap='gray')
plt.title("Actual Label: " + str(y_test[index]))
plt.show()

prediction = model.predict(np.array([x_test[index]]))
print("Predicted Label:", np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Predicted Label: 7

# %%
import matplotlib.pyplot as plt
import numpy as np

index = 100  # You can change this number later (0–9999)

plt.imshow(x_test[index], cmap='gray')
plt.title("Actual Label: " + str(y_test[index]))
plt.show()

prediction = model.predict(np.array([x_test[index]]))
print("Predicted Label:", np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted Label: 6

# %%
import matplotlib.pyplot as plt
import numpy as np

index = 1  # You can change this number later (0–9999)

plt.imshow(x_test[index], cmap='gray')
plt.title("Actual Label: " + str(y_test[index]))
plt.show()

prediction = model.predict(np.array([x_test[index]]))
print("Predicted Label:", np.argmax(prediction))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Predicted Label: 2
